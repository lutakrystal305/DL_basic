# %% [markdown]
# <a href="https://colab.research.google.com/github/lutakrystal305/DL_basic/blob/main/LogisticRegression_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nttuan8/DL_Tutorial.git
# Out:
# Cloning into 'DL_Tutorial'...
# remote: Enumerating objects: 113, done.
# remote: Total 113 (delta 0), reused 0 (delta 0), pack-reused 113
# Receiving objects: 100% (113/113), 60.69 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))
data = pd.read_csv("/content/DL_Tutorial/L2/dataset.csv").values
N, d = data.shape
print(N, d)
x = data[:, 0:d-1].reshape(-1, d-1)
print(x)
y = data[:, d-1].reshape(-1, 1)

plt.scatter(x[:10, 0], x[:10, 1], c='red', edgecolors='none', s=30, label='cho vay' )
plt.scatter(x[10:, 0], x[10:, 1], c='blue', edgecolors='none', s=30, label='từ chối' )
plt.legend(loc=1)
plt.xlabel('mức lương')
plt.ylabel('kinh nghiệm (năm)')

x = np.hstack((np.ones((N, 1)), x))
w = np.array([0., 0.1, 0.1]).reshape(-1, 1)
# Out:
# 20 3
# [[10.    1.  ]
#  [ 5.    2.  ]
#  [ 6.    1.8 ]
#  [ 7.    1.  ]
#  [ 8.    2.  ]
#  [ 9.    0.5 ]
#  [ 4.    3.  ]
#  [ 5.    2.5 ]
#  [ 8.    1.  ]
#  [ 4.    2.5 ]
#  [ 8.    0.1 ]
#  [ 7.    0.15]
#  [ 4.    1.  ]
#  [ 5.    0.8 ]
#  [ 7.    0.3 ]
#  [ 4.    1.  ]
#  [ 5.    0.5 ]
#  [ 6.    0.3 ]
#  [ 7.    0.2 ]
#  [ 8.    0.15]]

# %%
numOfIteration = 1000
cost = np.zeros((numOfIteration, 1))
lr = 0.001

for i in range(numOfIteration):
    y_pred = sigmoid(np.dot(x, w))
    cost[i] = -np.sum(np.multiply(y, np.log(y_pred)) + np.multiply(1-y, np.log(1-y_pred)))
    w = w - lr*np.dot(x.T, (y_pred-y))
    print(cost[i])
    #print(w)
# Vẽ đường phân cách.
t = 0.5
plt.plot((4, 10),(-(w[0]+4*w[1]+ np.log(1/t-1))/w[2], -(w[0] + 10*w[1]+ np.log(1/t-1))/w[2]), 'g')
plt.show()

np.save('weight.npy', w)
w = np.load('weight.npy')
print(w)
# Out:
# [2.85613441]
# [2.85595857]
# [2.85578275]
# [2.85560696]
# [2.85543118]
# [2.85525544]
# [2.85507971]
# [2.85490401]
# [2.85472833]
# [2.85455267]
# [2.85437704]
# [2.85420143]
# [2.85402585]
# [2.85385028]
# [2.85367474]
# [2.85349923]
# [2.85332374]
# [2.85314827]
# [2.85297282]
# [2.8527974]
# [2.852622]
# [2.85244662]
# [2.85227127]
# [2.85209594]
# [2.85192063]
# [2.85174535]
# [2.85157009]
# [2.85139485]
# [2.85121964]
# [2.85104445]
# [2.85086928]
# [2.85069414]
# [2.85051902]
# [2.85034392]
# [2.85016885]
# [2.84999379]
# [2.84981877]
# [2.84964376]
# [2.84946878]
# [2.84929382]
# [2.84911889]
# [2.84894398]
# [2.84876909]
# [2.84859422]
# [2.84841938]
# [2.84824456]
# [2.84806976]
# [2.84789499]
# [2.84772024]
# [2.84754551]
# [2.84737081]
# [2.84719613]
# [2.84702147]
# [2.84684684]
# [2.84667223]
# [2.84649764]
# [2.84632308]
# [2.84614853]
# [2.84597402]
# [2.84579952]
# [2.84562505]
# [2.8454506]
# [2.84527617]
# [2.84510177]
# [2.84492739]
# [2.84475303]
# [2.8445787]
# ...

# %%
numOfIteration = 1000
cost = np.zeros((numOfIteration,1))
learning_rate = 0.01
for i in range(1, numOfIteration):
    # Tính giá trị dự đoán
    y_predict = sigmoid(np.dot(x, w))
    cost[i] = -np.sum(np.multiply(y, np.log(y_predict)) + \
    np.multiply(1-y, np.log(1-y_predict)))
    # Gradient descent
    w = w - learning_rate * np.dot(x.T, y_predict-y)
    print(cost[i])
# Vẽ đường phân cách.
t = 0.5
plt.plot((4, 10),(-(w[0]+4*w[1]+ np.log(1/t-1))/w[2], -(w[0] + 10*w[1]+ \
np.log(1/t-1))/w[2]), 'g')
plt.show()
# Lưu weight dùng numpy.save(), định dạng '.npy'
np.save('weight logistic.npy', w)
# Load weight từ file ''.npy'
w = np.load('weight logistic.npy')
print(w)
# Out:
# [8.07016109]
# [8.05494969]
# [8.03981004]
# [8.02474098]
# [8.00974139]
# [7.99481021]
# [7.97994639]
# [7.96514893]
# [7.95041686]
# [7.93574924]
# [7.92114518]
# [7.9066038]
# [7.89212425]
# [7.87770572]
# [7.86334741]
# [7.84904857]
# [7.83480844]
# [7.82062632]
# [7.8065015]
# [7.7924333]
# [7.77842109]
# [7.76446421]
# [7.75056206]
# [7.73671403]
# [7.72291955]
# [7.70917805]
# [7.69548898]
# [7.68185182]
# [7.66826604]
# [7.65473113]
# [7.64124662]
# [7.62781201]
# [7.61442686]
# [7.60109069]
# [7.58780309]
# [7.5745636]
# [7.56137182]
# [7.54822734]
# [7.53512975]
# [7.52207867]
# [7.50907372]
# [7.49611454]
# [7.48320074]
# [7.47033199]
# [7.45750794]
# [7.44472824]
# [7.43199257]
# [7.4193006]
# [7.40665203]
# [7.39404653]
# [7.3814838]
# [7.36896355]
# [7.35648548]
# [7.34404931]
# [7.33165476]
# [7.31930156]
# [7.30698943]
# [7.29471811]
# [7.28248734]
# [7.27029687]
# [7.25814644]
# [7.24603582]
# [7.23396475]
# [7.22193301]
# [7.20994035]
# [7.19798655]
# [7.18607139]
# ...

# %%
from sklearn.linear_model import LogisticRegression

logr = LogisticRegression()
logr.fit(x, y)

wg = np.zeros( (3, 1) )
wg[0, 0] = logr.intercept_
print(logr.coef_)
wg[1:, 0] = logr.coef_

t = 0.5
plt.plot((4, 10),(-(wg[0]+4*wg[1]+ np.log(1/t-1))/wg[2], -(wg[0] + 10*wg[1]+ np.log(1/t-1))/wg[2]), 'g')
plt.show()

np.savez('weight.npz', a=logr.intercept_, b=logr.coef_)

k = np.load('weight.npz')
a = k['a']
b = k['b']
print(a, b)
# Out:
# [[0.66716139 2.09426755]]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [-6.4390718] [[0.66716139 2.09426755]]

# %%
# Tạo mô hình Logistic Regression và train
logreg = LogisticRegression()
logreg.fit(x, y)
# Lưu các biến của mô hình vào mảng
wg = np.zeros( (3, 1) )
wg[0, 0] = logreg.intercept_
wg[1:, 0] = logreg.coef_
# Vẽ đường phân cách
t = 0.5
plt.plot((4, 10),(-(wg[0]+4*wg[1]+ np.log(1/t-1))/wg[2], \
-(wg[0] + 10*wg[1]+ np.log(1/t-1))/wg[2]), 'g')
plt.show()
# Lưu các tham số dùng numpy.savez(), đỉnh dạng '.npz'
np.savez('w logistic.npz', a=logreg.intercept_, b=logreg.coef_)
# Load các tham số dùng numpy.load(), file '.npz'
k = np.load('w logistic.npz')
a = k['a']
b = k['b']
print(a, b)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [-6.4390718] [[0.66716139 2.09426755]]
